# %%
import pandas as pd

# %%
data = pd.read_csv('question_answer_combinations.csv')
data.head(10)
# Out:
#    false_index                 question  \
# 0            0  what is a bank account?
# 1            0  what is a bank account?
# 2            0  what is a bank account?
# 3            0  what is a bank account?
# 4            0  what is a bank account?
# 5            0  what is a bank account?
# 6            0  what is a bank account?
# 7            0   what's a bank account?
# 8            0   what's a bank account?
# 9            0   what's a bank account?
#
#                                               answer
# 0  A bank account is a deposit account held in a ...
# 1  A bank account is a deposit account held at a ...
# 2  A bank account is a deposit account held at a ...
# 3  A bank account is a deposit account in a finan...
# 4  A bank account is a deposit account in a finan...
# 5  A bank account is a bank account that allows a...
# 6  A bank account is a deposit account held at a ...
# 7  A bank account is a deposit account held in a ...
# ...

# %%
shuffled_df = data.sample(frac=1.0, random_state=42)
shuffled_df = shuffled_df.reset_index(drop=True)

# %%
shuffled_df.head()
# Out:
#    false_index                                           question  \
# 0          232  how do i apply for a personal loan in india wi...
# 1         1604  tell me the role of competition commission of ...
# 2         1320  is there any role of the insurance regulatory ...
# 3           84       how do i check my balance using sms banking?
# 4          280  how can i transfer money from india to another...
#
#                                               answer
# 0  You can apply for an unsecured personal loan i...
# 1  The cci promotes competition and ensures fair ...
# 2  The irdai regulates and supervises the insuran...
# 3  To check your account balance using sms bankin...
# 4  To transfer money from india to another countr...

# %%
shuffled_df.to_csv('FinalDataset.csv', index=False, columns=['question', 'answer'])
